# %% [markdown]
# # Gateway Kartplex driving analysis
#
# October 2025
#
# Goal is to process data recorded by the Sensor Logger app while doing practice laps at the Gateway Kartplex.
#
# Enrichments
#
# Add fields about the session / circuit:
# - circuit
# - visit number / date
# - session
# - session type (P for practice, R, Q)
# - session pro skill / pro skill change
#
# Enrichments
# - Since it uses the phone's commercial GPS for positioning have to use fusion techniques with IMU + GPS to get the true race trace.
# - Laps
# - Sectors
# - Turns
# - MPH
